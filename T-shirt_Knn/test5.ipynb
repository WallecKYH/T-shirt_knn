# %%
import pandas as pd
import seaborn as sns
from math import sqrt
import numpy as np


def div_conversion(df, column, div):
    return df[column].apply(lambda x: x/div)

male_df = pd.read_csv("male.csv")
Male_Tshirt = male_df[["stature", "weightkg"]]
Male_Tshirt["stature"] = div_conversion(Male_Tshirt, "stature", 10)
Male_Tshirt["weightkg"] = div_conversion(Male_Tshirt, "weightkg", 10)
m=(Male_Tshirt.dtypes=='float')
Male_Tshirt.loc[:,m]=Male_Tshirt.loc[:,m].astype(int)
Male_Tshirt.to_csv("T-Shirt_Male.csv", index=False)
male_shirt = pd.read_csv("T-Shirt_Male.csv")

female_df = pd.read_csv("female.csv")
Female_Tshirt = female_df[["stature", "weightkg"]]
Female_Tshirt["stature"] = div_conversion(Female_Tshirt, "stature", 10)
Female_Tshirt["weightkg"] = div_conversion(Female_Tshirt, "weightkg", 10)
m=(Female_Tshirt.dtypes=='float')
Female_Tshirt.loc[:,m]=Female_Tshirt.loc[:,m].astype(int)
Female_Tshirt.to_csv("T-Shirt_Female.csv", index=False)
female_shirt_with_size = pd.read_csv("T-Shirt_Female.csv")
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_33972\1346575248.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Male_Tshirt["stature"] = div_conversion(Male_Tshirt, "stature", 10)
# C:\Users\Alex\AppData\Local\Temp\ipykernel_33972\1346575248.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Male_Tshirt["weightkg"] = div_conversion(Male_Tshirt, "weightkg", 10)
# C:\Users\Alex\AppData\Local\Temp\ipykernel_33972\1346575248.py:15: SettingWithCopyWarning:
# ...

# %%
#Male T-shirt definition
Male_Tshirt.loc[(Male_Tshirt["stature"]>=197) | (Male_Tshirt["weightkg"]>=121), "SizeShirt"] = "XXXL"
Male_Tshirt.loc[(Male_Tshirt["stature"]<=196) & (Male_Tshirt["weightkg"]<=120), "SizeShirt"] = "XXL"
Male_Tshirt.loc[(Male_Tshirt["stature"]<=188) & (Male_Tshirt["weightkg"]<=100), "SizeShirt"] = "XL"
Male_Tshirt.loc[(Male_Tshirt["stature"]<=184) & (Male_Tshirt["weightkg"]<=95), "SizeShirt"] = "L"
Male_Tshirt.loc[(Male_Tshirt["stature"]<=180) & (Male_Tshirt["weightkg"]<=80), "SizeShirt"] = "M"
Male_Tshirt.loc[(Male_Tshirt["stature"]<=177) & (Male_Tshirt["weightkg"]<=68), "SizeShirt"] = "S"
Male_Tshirt.loc[(Male_Tshirt["stature"]<=165) & (Male_Tshirt["weightkg"]<=55), "SizeShirt"] = "XS"
Male_Tshirt.loc[(Male_Tshirt["stature"]<=150) & (Male_Tshirt["weightkg"]<=40), "SizeShirt"] = "XXS"

Male_Tshirt.to_csv("T-Shirt_Male.csv", index=False)

#Female T-shirt definition
Female_Tshirt.loc[(Female_Tshirt["stature"]>=190) | (Female_Tshirt["weightkg"]>=110), "SizeShirt"] = "XXXL"
Female_Tshirt.loc[(Female_Tshirt["stature"]<=190) & (Female_Tshirt["weightkg"]<=110), "SizeShirt"] = "XXXL"
Female_Tshirt.loc[(Female_Tshirt["stature"]<=180) & (Female_Tshirt["weightkg"]<=90), "SizeShirt"] = "XXL"
Female_Tshirt.loc[(Female_Tshirt["stature"]<=170) & (Female_Tshirt["weightkg"]<=80), "SizeShirt"] = "XL"
Female_Tshirt.loc[(Female_Tshirt["stature"]<=165) & (Female_Tshirt["weightkg"]<=75), "SizeShirt"] = "L"
Female_Tshirt.loc[(Female_Tshirt["stature"]<=155) & (Female_Tshirt["weightkg"]<=60), "SizeShirt"] = "M"
Female_Tshirt.loc[(Female_Tshirt["stature"]<=145) & (Female_Tshirt["weightkg"]<=50), "SizeShirt"] = "S"
Female_Tshirt.loc[(Female_Tshirt["stature"]<=130) & (Female_Tshirt["weightkg"]<=40), "SizeShirt"] = "XS"
Female_Tshirt.loc[(Female_Tshirt["stature"]<=129) & (Female_Tshirt["weightkg"]<=39), "SizeShirt"] = "XXS"

Female_Tshirt.to_csv("T_Shirt_Female.csv", index=False)
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_33972\1214780893.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Male_Tshirt.loc[(Male_Tshirt["stature"]>=197) | (Male_Tshirt["weightkg"]>=121), "SizeShirt"] = "XXXL"
# C:\Users\Alex\AppData\Local\Temp\ipykernel_33972\1214780893.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Female_Tshirt.loc[(Female_Tshirt["stature"]>=190) | (Female_Tshirt["weightkg"]>=110), "SizeShirt"] = "XXXL"

# %%
hue_size = ["XXXL","XXL", "XL", "L","M","S"]


lm = sns.lmplot(data= Female_Tshirt, x="weightkg", y="stature", hue="SizeShirt", hue_order=hue_size, legend=True, palette=dict(XXXL="#FF0000", XXL="#00FF00", XL="#0000FF", L="#FF00FF", M="#FFFF00", S="#00FFFF"))
fig = lm.fig
fig.suptitle("Female data", fontsize=16)
lm2 = sns.lmplot(data= Male_Tshirt, x="weightkg", y="stature", hue="SizeShirt",hue_order=hue_size, legend=True, palette=dict(XXXL="#FF0000", XXL="#00FF00", XL="#0000FF", L="#FF00FF", M="#FFFF00", S="#00FFFF"))
fig = lm2.fig
fig.suptitle("Male data", fontsize=16)
# Out:
# Text(0.5, 0.98, 'Male data')

# %%
dataset=pd.read_csv("T-Shirt_Male.csv")

# %%
dataset.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
X=dataset.iloc[:,0:1]

# %%
Y=dataset.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.5, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import  metrics
k_range = range(1,10)
scores = {}
scores_list = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, Y_train)
    Y_pred = knn.predict(X_test)
    scores[k] = metrics.accuracy_score(Y_test, Y_pred)
    scores_list.append(metrics.accuracy_score(Y_test, Y_pred))

# %%
x=k_range
y=scores_list

ymax = max(y)
xpos = y.index(ymax)
best_k_value = x[xpos]

# %%
#Input for weight
weight = input("Enter your weight (kg):")
#Input for height
height = input("Enter your height (cm):")
#Input for gender
gender = input("Are you male or female?")

df = pd.read_csv("T_Shirt_Female.csv") if gender == "female" else pd.read_csv("T-Shirt_Male.csv")

X_new = [[weight,height]]


def k_nearest_neighbor(df, P: list, k: int):
    def vec_abs(vec):
        return sqrt(sum([unit**2 for unit in vec]))

    def compute_vec(P_1, P_2):
        return [P_2[col] - P_1[col] for col in range(2)]

    points = []
    for row in range(df.shape[0]):
        point = [df["weightkg"][row], df["stature"][row]]
        vec = compute_vec(P, point)
        points.append((df["SizeShirt"][row] ,vec_abs(vec)))

    cluster = [size[0] for size in sorted(points, key=lambda y: y[1])[:k]]
    del points
    cluster_point = {i: cluster.count(i) for i in cluster}
    return max(cluster_point, key=cluster_point.get)



size2 = k_nearest_neighbor(df, [float(weight), float(height)], best_k_value)


print(f"Im predicting ur clothing size to : {size2}" )
# Out:
# Im predicting ur clothing size to : L
